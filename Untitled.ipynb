# %%
conda install numpy
# Out:
# ...
# Solving environment: unsuccessful initial attempt using frozen solve. Retrying with flexible solve.
# Solving environment: unsuccessful attempt using repodata from current_repodata.json, retrying with next repodata source.
# ...
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/continuum/anaconda/envs/python_37
#
#   added / updated specs:
#     - numpy
#
#
# The following NEW packages will be INSTALLED:
#
#   blas               pkgs/main/linux-64::blas-1.0-mkl
#   intel-openmp       pkgs/main/linux-64::intel-openmp-2021.4.0-h06a4308_3561
#   mkl                pkgs/main/linux-64::mkl-2021.4.0-h06a4308_640
#   mkl-service        pkgs/main/linux-64::mkl-service-2.4.0-py37h7f8727e_0
#   mkl_fft            pkgs/main/linux-64::mkl_fft-1.3.1-py37hd3c417c_0
#   mkl_random         pkgs/main/linux-64::mkl_random-1.2.2-py37h51133e4_0
#   numpy              pkgs/main/linux-64::numpy-1.21.5-py37h6c91a56_3
# ...

# %%
conda install notebook matplatlib
# Out:
# ...
# Solving environment: unsuccessful initial attempt using frozen solve. Retrying with flexible solve.
# ...
# Solving environment: unsuccessful initial attempt using frozen solve. Retrying with flexible solve.
#
# PackagesNotFoundError: The following packages are not available from current channels:
#
#   - matplatlib
#
# Current channels:
#
#   - https://repo.anaconda.com/pkgs/main/linux-64
#   - https://repo.anaconda.com/pkgs/main/noarch
#   - https://repo.anaconda.com/pkgs/r/linux-64
#   - https://repo.anaconda.com/pkgs/r/noarch
#
# To search for alternate channels that may provide the conda package you're
# looking for, navigate to
#
#     https://anaconda.org
#
# and use the search bar at the top of the page.
#
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
conda install matplotlib
# Out:
# ...
# Solving environment: unsuccessful initial attempt using frozen solve. Retrying with flexible solve.
# Solving environment: unsuccessful attempt using repodata from current_repodata.json, retrying with next repodata source.
# ...
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/continuum/anaconda/envs/python_37
#
#   added / updated specs:
#     - matplotlib
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     fontconfig-2.14.1          |       hef1e5e3_0         284 KB  defaults
#     freetype-2.11.0            |       h70c0345_0         618 KB  defaults
#     glib-2.69.1                |       h4ff587b_1         1.7 MB  defaults
#     kiwisolver-1.3.2           |   py37h295c915_0          80 KB  defaults
#     libdeflate-1.8             |       h7f8727e_5          51 KB  defaults
# ...

# %%
conda install notebook
# Out:
# ...
# Solving environment: unsuccessful initial attempt using frozen solve. Retrying with flexible solve.
# Solving environment: unsuccessful attempt using repodata from current_repodata.json, retrying with next repodata source.
# ...
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/continuum/anaconda/envs/python_37
#
#   added / updated specs:
#     - notebook
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     cffi-1.15.1                |   py37h74dc2b5_0         227 KB  defaults
#     ------------------------------------------------------------
#                                            Total:         227 KB
#
# The following NEW packages will be INSTALLED:
#
#   anyio              pkgs/main/linux-64::anyio-3.5.0-py37h06a4308_0
#   argon2-cffi        pkgs/main/linux-64::argon2-cffi-20.1.0-py37h27cfd23_1
# ...
